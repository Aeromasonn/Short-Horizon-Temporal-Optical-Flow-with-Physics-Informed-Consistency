# %%
from model_v2_w6ms3.My.Encoder_sober import *
from model_v2_w6ms3.My.train_v22_hard_fbmask import *
from torch.utils.data import Dataset, DataLoader
from model_v2_w6ms3.DataLoader import *

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import math
from dataclasses import dataclass
from typing import List, Dict, Optional, Tuple
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cfg = {
  "data": {
    "data_root": "../../Data",
    "stats_file": "stats.json",
    "crop_size": [
      352,
      1216
    ],
    "seq_len": 4,
    "center_frame_idx": 10,
    "split": "training",
    "image_folder": "image_2",
    "flow_type": "flow_occ",
    "disp_type": "disp_occ",
    "normalize": True,
    "return_pair_only": False
  },
  "model": {
    "pair_feat_ch": 64,
    "corr_radius": 4,
    "pair_embed_ch": 128,
    "predict_flow_init": True,
    "visual_in_ch": 3,
    "visual_base_ch": 32,
    "visual_out_ch": 64,
    "motion_in_ch": 128,
    "motion_hidden_ch": 128,
    "motion_out_ch": 64,
    "fusion_visual_ch": 64,
    "fusion_motion_ch": 64,
    "fusion_hidden_ch": 128,
    "fusion_out_ch": 128,
    "uno_use_valid_mask": True,
    "uno_hidden_channels": 64,
    "uno_lifting_channels": 128,
    "uno_projection_channels": 128,
    "uno_n_layers": 4,
    "uno_out_channels": [
      64,
      128,
      128,
      64
    ],
    "uno_n_modes": [
      [
        16,
        16
      ],
      [
        12,
        12
      ],
      [
        12,
        12
      ],
      [
        16,
        16
      ]
    ],
    "uno_scalings": [
      [
        1.0,
        1.0
      ],
      [
        0.5,
        0.5
      ],
      [
        2.0,
        2.0
      ],
      [
        1.0,
        1.0
      ]
    ],
    "decoder_in_ch": 128,
    "decoder_hidden_ch": 64,
    "decoder_upsample": 8,
    "decoder_use_prev_flow": True
  },
  "train": {
    "batch_size": 2,
    "num_epochs": 400,
    "lr": 0.0001,
    "weight_decay": 0.0001,
    "num_workers": 0,
    "shuffle": True,
    "pin_memory": True,
    "log_every_n_steps": 10,
    "seed": 42,
    "save_epoch_checkpoints": [
      50,
      100,
      150,
      200
    ]
  },
  "loss": {
    "lambda_temp": 0.03,
    "lambda_smooth": 0.01,
    "lambda_self": 0.1,
    "lambda_edge_weight": 1.0,
    "photo_lambda_l1": 0.15,
    "photo_lambda_ssim": 0.85,
    "photo_lambda_census": 0.3,
    "photo_census_patch": 7,
    "photo_multiframe_reduction": "mean",
    "photo_use_confidence": True,
    "photo_texture_floor": 0.05,
    "photo_robust_beta": 10.0,
    "photo_use_fb_consistency": True,
    "photo_bidirectional": True,
    "fb_alpha": 0.01,
    "fb_beta": 0.5,
    "fb_gamma": 2.0,
    "fb_conf_floor": 0.05,
    "lambda_acc_photo": 0.05,
    "lambda_acc_smooth": 0.0,
    "accum_max_skip": 2,
    "lambda_fb": 0.01,
    "fb_loss_robust_eps": 0.01,
    "photo_use_hard_fb_mask": True,
    "fb_mask_alpha1": 0.01,
    "fb_mask_alpha2": 0.5
  },
  "experiment": {
    "experiment_name": "v22_hard_fbmask",
    "save_dir": "checkpoints",
    "tensorboard_dir": "runs",
    "checkpoint_name": "fullpipeline_v22_latest.pth",
    "best_checkpoint_name": "fullpipeline_v22_best.pth",
    "config_dump_name": "config_v22_hard_fbmask.json"
  }
}

# %%
def read_rgb_img(path):
    img = cv2.imread(str(path))
    if img is None:
        raise FileNotFoundError(f"Image not found: {path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return img.astype(np.float32) / 255.0


def read_kitti_flow(path):
    flow_png = cv2.imread(str(path), cv2.IMREAD_UNCHANGED)
    if flow_png is None:
        raise FileNotFoundError(f"Flow not found: {path}")

    flow_png = flow_png.astype(np.float32)

    valid = flow_png[:, :, 0] > 0
    u = (flow_png[:, :, 2] - 32768.0) / 64.0
    v = (flow_png[:, :, 1] - 32768.0) / 64.0

    flow = np.stack([u, v], axis=-1).astype(np.float32)
    valid = valid.astype(np.float32)

    return flow, valid


def read_kitti_disp(path):
    disp_png = cv2.imread(str(path), cv2.IMREAD_UNCHANGED)
    if disp_png is None:
        raise FileNotFoundError(f"Disparity not found: {path}")

    disp_png = disp_png.astype(np.float32)
    disp = disp_png / 256.0
    valid = (disp_png > 0).astype(np.float32)

    return disp, valid


def read_obj_map(path):
    obj = cv2.imread(str(path), cv2.IMREAD_UNCHANGED)
    if obj is None:
        raise FileNotFoundError(f"Object map not found: {path}")

    return obj.astype(np.int32)


def center_crop(arr, crop_size):
    crop_h, crop_w = crop_size
    h, w = arr.shape[:2]

    if crop_h > h or crop_w > w:
        raise RuntimeError(f"Crop size {crop_size} larger than image size {h}x{w}")

    top = (h - crop_h) // 2
    left = (w - crop_w) // 2

    if arr.ndim == 3:
        return arr[top:top + crop_h, left:left + crop_w, :]
    elif arr.ndim == 2:
        return arr[top:top + crop_h, left:left + crop_w]
    else:
        raise RuntimeError(f"Unexpected arr.ndim={arr.ndim}")


def obj_map_to_boxes(obj_map, min_area=20, return_masks=False):
    """
    obj_map:
        [H,W], integer instance id map

    Returns detection target:
        boxes:  [N,4], xyxy
        labels: [N], all ones
        obj_ids:[N]
        optional masks: [N,H,W]
    """

    boxes = []
    labels = []
    obj_ids = []
    masks = []

    unique_ids = np.unique(obj_map)

    for obj_id in unique_ids:
        if obj_id == 0:
            continue

        mask = obj_map == obj_id
        ys, xs = np.where(mask)

        if len(xs) == 0:
            continue

        x1 = xs.min()
        x2 = xs.max()
        y1 = ys.min()
        y2 = ys.max()

        w = x2 - x1 + 1
        h = y2 - y1 + 1
        area = w * h

        if area < min_area:
            continue

        boxes.append([x1, y1, x2, y2])
        labels.append(1)
        obj_ids.append(int(obj_id))

        if return_masks:
            masks.append(mask.astype(np.uint8))

    target = {
        "boxes": torch.tensor(boxes, dtype=torch.float32),
        "labels": torch.tensor(labels, dtype=torch.long),
        "obj_ids": torch.tensor(obj_ids, dtype=torch.long),
    }

    if return_masks:
        if len(masks) > 0:
            target["masks"] = torch.from_numpy(np.stack(masks, axis=0)).to(torch.uint8)
        else:
            H, W = obj_map.shape
            target["masks"] = torch.zeros((0, H, W), dtype=torch.uint8)

    return target


def detection_collate_fn(batch):
    out = {}

    for k in batch[0].keys():
        if k == "label":
            out[k] = [b[k] for b in batch]
        elif isinstance(batch[0][k], torch.Tensor):
            out[k] = torch.stack([b[k] for b in batch], dim=0)
        else:
            out[k] = [b[k] for b in batch]

    return out


class TempFlowDataset_ObjMap(Dataset):
    """
    KITTI Flow / Scene Flow dataset with aligned obj_map labels.

    Uses:
        Additional_frames/training/image_2/000000_08.png ...
        Flow/training/flow_occ/000000_10.png
        Flow/training/obj_map/000000_10.png

    Output:
        imgs:          [T,3,H,W]
        flow:          [2,H,W]
        valid:         [H,W]
        label:         dict with boxes/labels/obj_ids
        seq_id:        str, e.g. "000000"
        flow_frame:    long, usually 10
        frame_indices: [T]
    """

    def __init__(
        self,
        root,
        split="training",
        image_folder="image_2",
        flow_type="flow_occ",
        disp_type="disp_occ",
        seq_len=5,
        crop_size=(352, 1216),
        normalize=True,
        stats_in=None,
        return_pair_only=False,
        min_obj_area=20,
        return_masks=False,
        require_obj_map=True,
    ):
        super().__init__()

        self.root = Path(root)
        self.split = split
        self.image_folder = image_folder
        self.flow_type = flow_type
        self.disp_type = disp_type
        self.seq_len = seq_len
        self.crop_size = crop_size
        self.normalize = normalize
        self.stats_in = stats_in
        self.return_pair_only = return_pair_only
        self.min_obj_area = min_obj_area
        self.return_masks = return_masks
        self.require_obj_map = require_obj_map

        self.additional_frames_dir = (
            self.root / "Additional_frames" / split / image_folder
        )

        self.flow_dir = self.root / "Flow" / split / flow_type
        self.obj_map_dir = self.root / "Flow" / split / "obj_map"

        self.disp0_dir = self.root / "Flow" / split / f"{disp_type}_0"
        self.disp1_dir = self.root / "Flow" / split / f"{disp_type}_1"

        if not self.additional_frames_dir.exists():
            raise FileNotFoundError(f"Missing image folder: {self.additional_frames_dir}")

        if not self.flow_dir.exists():
            raise FileNotFoundError(f"Missing flow folder: {self.flow_dir}")

        if self.require_obj_map and not self.obj_map_dir.exists():
            raise FileNotFoundError(f"Missing obj_map folder: {self.obj_map_dir}")

        if not self.disp0_dir.exists():
            raise FileNotFoundError(f"Missing disparity folder: {self.disp0_dir}")

        if not self.disp1_dir.exists():
            raise FileNotFoundError(f"Missing disparity folder: {self.disp1_dir}")

        self.samples = self._build_samples()

        if len(self.samples) == 0:
            raise RuntimeError("No valid samples found.")

        self.stats = self._load_stats()

    def _build_samples(self):
        flow_files = sorted(self.flow_dir.glob("*.png"))
        samples = []

        half = self.seq_len // 2

        for flow_path in flow_files:
            stem = flow_path.stem          # e.g. 000030_10
            seq_id, frame_str = stem.split("_")
            flow_frame = int(frame_str)

            if self.return_pair_only:
                frame_indices = [flow_frame, flow_frame + 1]
            else:
                start = flow_frame - half + 1
                frame_indices = list(range(start, start + self.seq_len))

            img_paths = []

            valid_sample = True
            for t in frame_indices:
                img_path = self.additional_frames_dir / f"{seq_id}_{t:02d}.png"

                if not img_path.exists():
                    valid_sample = False
                    break

                img_paths.append(str(img_path))

            if not valid_sample:
                continue

            obj_map_path = self.obj_map_dir / f"{seq_id}_{flow_frame:02d}.png"

            if self.require_obj_map and not obj_map_path.exists():
                continue

            disp_name = f"{seq_id}_{flow_frame:02d}.png"
            disp0_path = self.disp0_dir / disp_name
            disp1_path = self.disp1_dir / disp_name

            if not disp0_path.exists() or not disp1_path.exists():
                continue

            samples.append({
                "seq_id": seq_id,
                "flow_frame": flow_frame,
                "frame_indices": frame_indices,
                "img_paths": img_paths,
                "flow_path": str(flow_path),
                "obj_map_path": str(obj_map_path),
                "disp0_path": str(disp0_path),
                "disp1_path": str(disp1_path),
            })

        return samples

    def _load_stats(self):
        if self.stats_in is not None and os.path.exists(self.stats_in):
            with open(self.stats_in, "r") as f:
                return json.load(f)

        stats = self.compute_stats()

        if self.stats_in is not None:
            dirname = os.path.dirname(self.stats_in)
            if dirname != "":
                os.makedirs(dirname, exist_ok=True)

            with open(self.stats_in, "w") as f:
                json.dump(stats, f, indent=2)

        return stats

    def compute_stats(self):
        channel_sum = np.zeros(3, dtype=np.float64)
        channel_sq_sum = np.zeros(3, dtype=np.float64)
        pixel_count = 0

        seen = set()

        for sample in self.samples:
            for img_path in sample["img_paths"]:
                if img_path in seen:
                    continue

                seen.add(img_path)

                img = read_rgb_img(img_path)

                if self.crop_size is not None:
                    img = center_crop(img, self.crop_size)

                h, w, _ = img.shape
                flat = img.reshape(-1, 3)

                channel_sum += flat.sum(axis=0)
                channel_sq_sum += (flat ** 2).sum(axis=0)
                pixel_count += h * w

        mean = channel_sum / pixel_count
        var = channel_sq_sum / pixel_count - mean ** 2
        std = np.sqrt(np.maximum(var, 1e-8))

        return {
            "mean": mean.tolist(),
            "std": std.tolist(),
            "num_unique_frames": len(seen),
            "num_samples": len(self.samples),
        }

    def _normalize_img(self, img):
        mean = np.array(self.stats["mean"], dtype=np.float32)
        std = np.array(self.stats["std"], dtype=np.float32)
        return (img - mean) / std

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]

        imgs = []

        for img_path in sample["img_paths"]:
            img = read_rgb_img(img_path)

            if self.crop_size is not None:
                img = center_crop(img, self.crop_size)

            if self.normalize:
                img = self._normalize_img(img)

            img = torch.from_numpy(img).permute(2, 0, 1).contiguous()
            imgs.append(img)

        imgs = torch.stack(imgs, dim=0)

        flow, valid = read_kitti_flow(sample["flow_path"])

        if self.crop_size is not None:
            flow = center_crop(flow, self.crop_size)
            valid = center_crop(valid, self.crop_size)

        flow = torch.from_numpy(flow).permute(2, 0, 1).contiguous()
        valid = torch.from_numpy(valid).contiguous()

        obj_map = read_obj_map(sample["obj_map_path"])

        if self.crop_size is not None:
            obj_map = center_crop(obj_map, self.crop_size)

        target = obj_map_to_boxes(
            obj_map,
            min_area=self.min_obj_area,
            return_masks=self.return_masks,
        )

        disp0, disp_valid0 = read_kitti_disp(sample["disp0_path"])
        disp1, disp_valid1 = read_kitti_disp(sample["disp1_path"])

        if self.crop_size is not None:
            disp0 = center_crop(disp0, self.crop_size)
            disp1 = center_crop(disp1, self.crop_size)
            disp_valid0 = center_crop(disp_valid0, self.crop_size)
            disp_valid1 = center_crop(disp_valid1, self.crop_size)

        disp0 = torch.from_numpy(disp0).unsqueeze(0).contiguous()
        disp1 = torch.from_numpy(disp1).unsqueeze(0).contiguous()
        disp_valid0 = torch.from_numpy(disp_valid0).unsqueeze(0).contiguous()
        disp_valid1 = torch.from_numpy(disp_valid1).unsqueeze(0).contiguous()

        disp = torch.stack([disp0, disp1], dim=0)
        disp_valid = torch.stack([disp_valid0, disp_valid1], dim=0)

        output = {
            "imgs": imgs,
            "flow": flow,
            "valid": valid,
            "label": target,
            "obj_map": torch.from_numpy(obj_map).long(),
            "disp": disp,
            "disp_valid": disp_valid,
            "seq_id": sample["seq_id"],
            "flow_frame": torch.tensor(sample["flow_frame"], dtype=torch.long),
            "frame_indices": torch.tensor(sample["frame_indices"], dtype=torch.long),
        }

        if imgs.shape[0] >= 2:
            gt_src = sample["flow_frame"]
            indices = sample["frame_indices"]

            if gt_src in indices and (gt_src + 1) in indices:
                src_pos = indices.index(gt_src)
                tgt_pos = indices.index(gt_src + 1)

                output["img_src"] = imgs[src_pos]
                output["img_tgt"] = imgs[tgt_pos]
                output["src_idx_in_seq"] = torch.tensor(src_pos, dtype=torch.long)
                output["tgt_idx_in_seq"] = torch.tensor(tgt_pos, dtype=torch.long)

        return output

# %%
set_seed(cfg["train"]["seed"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dataset = TempFlowDataset_ObjMap(
        root=cfg["data"]["data_root"],
        split=cfg["data"]["split"],
        image_folder=cfg["data"]["image_folder"],
        flow_type=cfg["data"]["flow_type"],
        disp_type=cfg["data"]["disp_type"],
        seq_len=cfg["data"]["seq_len"],
        #center_frame_idx=cfg["data"]["center_frame_idx"],
        crop_size=tuple(cfg["data"]["crop_size"]),
        normalize=cfg["data"]["normalize"],
        stats_in=cfg["data"]["stats_file"],
        return_pair_only=cfg["data"]["return_pair_only"],
    )

train_loader = DataLoader(
        dataset,
        batch_size=cfg["train"]["batch_size"],
        shuffle=cfg["train"]["shuffle"],
        num_workers=cfg["train"]["num_workers"],
        pin_memory=cfg["train"]["pin_memory"],
        collate_fn=detection_collate_fn
    )

modules = build_modules(cfg, device)
optimizer = torch.optim.AdamW(
        [p for module in modules.values() for p in module.parameters()],
        lr=1e-4,
        weight_decay=1e-4
    )

# %%
def forward_pipeline(modules, imgs, valid, uno_use_valid_mask=True):
        pair_encoder = modules['pair_encoder'].to(device)
        pair_out = pair_encoder(imgs)
        #pair_out = modules["pair_encoder"](imgs).to(device)
        pair_feats = pair_out["pair_feats"].to(device)
        flow_inits = pair_out["flow_inits"].to(device)
        corrs = pair_out["corrs"].to(device)

        if flow_inits is None:
            raise RuntimeError("v19 UNO integration requires predict_flow_init=True in the pair encoder.")

        visual_feats = modules["visual_branch"](imgs)
        motion_feats = modules["motion_branch"](pair_feats)
        fused_seq = modules["fusion"](visual_feats, motion_feats)

        valid_ds = None
        if uno_use_valid_mask:
            valid_ds = downsample_valid_mask(valid, fused_seq.shape[-2:])

        uno_in = build_uno_input_2d(fused_seq, flow_inits, valid_mask=valid_ds)
        uno_feat = modules["uno"](uno_in)

        b, tm, _, h, w = fused_seq.shape
        latent_delta = modules["latent_head"](uno_feat, b, tm, h, w)
        refined_seq = fused_seq + latent_delta

        flows, flow_residuals = modules["decoder"](refined_seq, flow_inits=flow_inits)

        return {
            "flows": flows,
            "flow_inits": flow_inits,
            "pair_feats": pair_feats,
            "corrs": corrs,
            "fused_seq": fused_seq,
            "latent_delta": latent_delta,
            "refined_seq": refined_seq,
            "flow_residuals": flow_residuals,
        }

# %%
def load_checkpoint(ckpt_path, modules, device, optimizer=None, strict=True):
    ckpt = torch.load(ckpt_path, map_location=device)

    # ---- load module weights ----
    for name, module in modules.items():
        key = f"{name}_state_dict"
        if key in ckpt:
            module.load_state_dict(ckpt[key], strict=strict)
        else:
            print(f"[Warning] Missing key: {key}")

        module.to(device)

    # ---- load optimizer (optional) ----
    if optimizer is not None and "optimizer_state_dict" in ckpt:
        optimizer.load_state_dict(ckpt["optimizer_state_dict"])

    # ---- metadata ----
    epoch = ckpt.get("epoch", None)
    stats = ckpt.get("stats", None)
    config = ckpt.get("config", None)

    print(f"Loaded checkpoint complete from: {ckpt_path} (epoch={epoch})")

    return {
        "epoch": epoch,
        "stats": stats,
        "config": config,
    }

# %%
meta = load_checkpoint(
    ckpt_path="../../model_v2_w6ms3/My/fullpipeline_v22_best.pth",
    modules=modules,
    device=device,
    optimizer=optimizer,   # optional
)
for m in modules.values():
    m.to(device)
    print(m)
# Out:
# Loaded checkpoint complete from: ../../model_v2_w6ms3/My/fullpipeline_v22_best.pth (epoch=387)
# SequencePairEncoder(
#   (pair_encoder): PairwiseFlowEncoder(
#     (sobel): SobelEdgeExtractor()
#     (feature_net): FeaturePyramidCNN(
#       (net): Sequential(
#         (0): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(4, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (1): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (2): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (3): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (4): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (5): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#       )
#     )
#     (corr): LocalCorrelation()
#     (fuse): Sequential(
#       (0): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(209, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#     (flow_head): Sequential(
#       (0): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )
# VisualBranchCNN(
#   (encoder): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (2): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (3): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (4): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (5): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (6): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (7): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#   )
# )
# MotionBranchCNN(
#   (encoder): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (2): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (3): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#   )
# )
# SpatialTemporalFusion_timeAware(
#   (local_proj): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (2): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#   )
#   (residual_proj): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
# )
# UNO(
#   (lifting): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(403, 128, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (fno_blocks): ModuleList(
#     (0): FNOBlocks(
#       (convs): ModuleList(
#         (0): SpectralConv(
#           (weight): DenseTensor(shape=torch.Size([64, 64, 16, 9]), rank=None)
#         )
#       )
#       (fno_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#       (channel_mlp): ModuleList(
#         (0): ChannelMLP(
#           (fcs): ModuleList(
#             (0): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#             (1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (channel_mlp_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#     )
#     (1): FNOBlocks(
#       (convs): ModuleList(
#         (0): SpectralConv(
#           (weight): DenseTensor(shape=torch.Size([64, 128, 12, 7]), rank=None)
#         )
#       )
#       (fno_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#       (channel_mlp): ModuleList(
#         (0): ChannelMLP(
#           (fcs): ModuleList(
#             (0): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#             (1): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (channel_mlp_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#     )
#     (2): FNOBlocks(
#       (convs): ModuleList(
#         (0): SpectralConv(
#           (weight): DenseTensor(shape=torch.Size([256, 128, 12, 7]), rank=None)
#         )
#       )
#       (fno_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#       (channel_mlp): ModuleList(
#         (0): ChannelMLP(
#           (fcs): ModuleList(
#             (0): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#             (1): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (channel_mlp_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#     )
#     (3): FNOBlocks(
#       (convs): ModuleList(
#         (0): SpectralConv(
#           (weight): DenseTensor(shape=torch.Size([192, 64, 16, 9]), rank=None)
#         )
#       )
#       (fno_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(192, 64, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#       (channel_mlp): ModuleList(
#         (0): ChannelMLP(
#           (fcs): ModuleList(
#             (0): Conv1d(64, 32, kernel_size=(1,), stride=(1,))
#             (1): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (channel_mlp_skips): ModuleList(
#         (0): Flattened1dConv(
#           (conv): Conv1d(192, 64, kernel_size=(1,), stride=(1,), bias=False)
#         )
#       )
#     )
#   )
#   (horizontal_skips): ModuleDict(
#     (0): Flattened1dConv(
#       (conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,), bias=False)
#     )
#     (1): Flattened1dConv(
#       (conv): Conv1d(128, 128, kernel_size=(1,), stride=(1,), bias=False)
#     )
#   )
#   (projection): ChannelMLP(
#     (fcs): ModuleList(
#       (0): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       (1): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#     )
#   )
# )
# UNOLatentResidualHead(
#   (out_proj): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#     )
#     (1): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# FlowDecoder(
#   (decoder): FlowDecoderSingle(
#     (conv0): Sequential(
#       (0): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(130, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#     (flow_head): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (low_refine): Sequential(
#       (0): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(66, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#       (1): ConvBlock(
#         (block): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         )
#       )
#     )
#     (low_delta_head): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (context_net): ContextNet(
#       (net): Sequential(
#         (0): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (1): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (2): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (3): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(8, 8), dilation=(8, 8), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (4): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(16, 16), dilation=(16, 16), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (5): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (6): Conv2d(64, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (up_refiner): LearnedUpsampleRefiner(
#       (refine): Sequential(
#         (0): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(66, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (1): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (2): ConvBlock(
#           (block): Sequential(
#             (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): LeakyReLU(negative_slope=0.1, inplace=True)
#           )
#         )
#         (3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
# )

# %%
batch = next(iter(train_loader))
out = forward_pipeline(modules, batch["imgs"].to(device), batch["valid"].to(device), uno_use_valid_mask=True)
print(out['flows'].shape)
# Out:
# torch.Size([2, 3, 2, 352, 1216])

# %%
import model_v2_w6ms3.Detector as Detector
import importlib
importlib.reload(Detector)
from model_v2_w6ms3.Detector import *

# %%
ID_TO_CLASS_NAME = {
    1: "object",
}

detector = FlowObjectDetector(
    num_classes=2,
    in_ch=3,          # u, v, magnitude
    pretrained_backbone=True,
)


optimizer = torch.optim.AdamW(
    detector.parameters(),
    lr=1e-4,
    weight_decay=1e-4,
)

trainer = FlowDetectionTrainer(
    flow_modules=modules,
    detector=detector,
    train_loader=train_loader,
    val_loader=None,
    optimizer=optimizer,
    device=device,
    flow_index=1,
    use_mag=True,
    use_valid=False,
    freeze_flow=True,
)

# %%
trainer.fit(epochs=10)
# Out:
# Train epoch 1:   6%|▌         | 6/100 [01:32<24:11, 15.44s/it, loss=1.1, cls=0.54, box=0.0702, obj=0.452, rpn=0.0341]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 trainer.fit(epochs=10)
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\Detector.py:649, in FlowDetectionTrainer.fit(self, epochs)
#     646 history = []
#     648 for epoch in range(1, epochs + 1):
# --> 649     train_loss = self.train_one_epoch(epoch)
#     651     print(f"[Epoch {epoch}] train_loss = {train_loss:.4f}")
#     653     history.append({
#     654         "epoch": epoch,
#     655         "train_loss": train_loss,
#     656     })
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\Detector.py:457, in FlowDetectionTrainer.train_one_epoch(self, epoch)
#     455 if self.freeze_flow:
#     456     with torch.no_grad():
# --> 457         flow_out = forward_pipeline(
#     458             imgs=imgs,
#     459             valid=valid,
#     460             modules=self.flow_modules
#     461         )
#     462 else:
#     463     flow_out = forward_pipeline(
#     464         imgs=imgs,
#     465         valid=valid,
#     466         modules=self.flow_modules
#     467     )
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\Detector.py:307, in forward_pipeline(modules, imgs, valid, uno_use_valid_mask, device)
#     304 latent_delta = modules["latent_head"](uno_feat, b, tm, h, w)
#     305 refined_seq = fused_seq + latent_delta
# --> 307 flows, flow_residuals = modules["decoder"](refined_seq, flow_inits=flow_inits)
#     309 return {
#     310     "flows": flows,
#     311     "flow_inits": flow_inits,
#    (...)
#     317     "flow_residuals": flow_residuals,
#     318 }
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\My\Decoders_v20_fixed2.py:160, in FlowDecoder.forward(self, fused_seq, flow_inits)
#     158 for t in range(tm):
#     159     z = fused_seq[:, t]
# --> 160     flow_res = self.decoder(z, flow_prev if self.use_prev_flow else None)
#     161     _, _, H, W = flow_res.shape
#     162     if flow_inits is not None:
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\My\Decoders_v20_fixed2.py:123, in FlowDecoderSingle.forward(self, z, flow_prev)
#     120 flow_low = self.flow_head(feat)
#     122 low_x = self.low_refine(torch.cat([feat, flow_low], dim=1))
# --> 123 flow_low = flow_low + self.low_delta_head(low_x) + self.context_net(low_x)
#     125 flow_high = self.up_refiner(feat, flow_low, self.upsample)
#     126 return flow_high
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\My\Decoders_v20_fixed2.py:44, in ContextNet.forward(self, x)
#      43 def forward(self, x):
# ---> 44     return self.net(x)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\STATS-402-Project\model_v2_w6ms3\My\Decoders_v20_fixed2.py:26, in ConvBlock.forward(self, x)
#      25 def forward(self, x):
# ---> 26     return self.block(x)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File D:\PyCharm 2024.2.1\Projects\pythonProject\.venv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
def load_detector_ckpt(ckpt_path, device="cuda"):
    detector = FlowObjectDetector(
        num_classes=2,
        in_ch=3,                  # u, v, magnitude
        pretrained_backbone=False # weights will come from ckpt
    ).to(device)

    ckpt = torch.load(ckpt_path, map_location=device)

    detector.load_state_dict(ckpt["detector_state_dict"])
    detector.eval()

    print(f"Loaded checkpoint: {ckpt_path}")
    print(f"Epoch: {ckpt.get('epoch', 'unknown')}")

    return detector, ckpt

ckpt_path = "../../model_v2_w6ms3/ckpts/detector_epoch_010.pt"
detector, ckpt = load_detector_ckpt(ckpt_path, device=device)

for name, param in detector.named_parameters():
     print(name, param.shape, param.requires_grad)
# Out:
# Loaded checkpoint: ../../model_v2_w6ms3/ckpts/detector_epoch_010.pt
# Epoch: 10
# detector.backbone.body.0.0.weight torch.Size([16, 3, 3, 3]) True
# detector.backbone.body.0.1.weight torch.Size([16]) True
# detector.backbone.body.0.1.bias torch.Size([16]) True
# detector.backbone.body.1.block.0.0.weight torch.Size([16, 1, 3, 3]) True
# detector.backbone.body.1.block.0.1.weight torch.Size([16]) True
# detector.backbone.body.1.block.0.1.bias torch.Size([16]) True
# detector.backbone.body.1.block.1.0.weight torch.Size([16, 16, 1, 1]) True
# detector.backbone.body.1.block.1.1.weight torch.Size([16]) True
# detector.backbone.body.1.block.1.1.bias torch.Size([16]) True
# detector.backbone.body.2.block.0.0.weight torch.Size([64, 16, 1, 1]) True
# detector.backbone.body.2.block.0.1.weight torch.Size([64]) True
# detector.backbone.body.2.block.0.1.bias torch.Size([64]) True
# detector.backbone.body.2.block.1.0.weight torch.Size([64, 1, 3, 3]) True
# detector.backbone.body.2.block.1.1.weight torch.Size([64]) True
# detector.backbone.body.2.block.1.1.bias torch.Size([64]) True
# detector.backbone.body.2.block.2.0.weight torch.Size([24, 64, 1, 1]) True
# detector.backbone.body.2.block.2.1.weight torch.Size([24]) True
# detector.backbone.body.2.block.2.1.bias torch.Size([24]) True
# detector.backbone.body.3.block.0.0.weight torch.Size([72, 24, 1, 1]) True
# detector.backbone.body.3.block.0.1.weight torch.Size([72]) True
# detector.backbone.body.3.block.0.1.bias torch.Size([72]) True
# detector.backbone.body.3.block.1.0.weight torch.Size([72, 1, 3, 3]) True
# detector.backbone.body.3.block.1.1.weight torch.Size([72]) True
# detector.backbone.body.3.block.1.1.bias torch.Size([72]) True
# detector.backbone.body.3.block.2.0.weight torch.Size([24, 72, 1, 1]) True
# detector.backbone.body.3.block.2.1.weight torch.Size([24]) True
# detector.backbone.body.3.block.2.1.bias torch.Size([24]) True
# detector.backbone.body.4.block.0.0.weight torch.Size([72, 24, 1, 1]) True
# detector.backbone.body.4.block.0.1.weight torch.Size([72]) True
# detector.backbone.body.4.block.0.1.bias torch.Size([72]) True
# detector.backbone.body.4.block.1.0.weight torch.Size([72, 1, 5, 5]) True
# detector.backbone.body.4.block.1.1.weight torch.Size([72]) True
# detector.backbone.body.4.block.1.1.bias torch.Size([72]) True
# detector.backbone.body.4.block.2.fc1.weight torch.Size([24, 72, 1, 1]) True
# detector.backbone.body.4.block.2.fc1.bias torch.Size([24]) True
# detector.backbone.body.4.block.2.fc2.weight torch.Size([72, 24, 1, 1]) True
# detector.backbone.body.4.block.2.fc2.bias torch.Size([72]) True
# detector.backbone.body.4.block.3.0.weight torch.Size([40, 72, 1, 1]) True
# detector.backbone.body.4.block.3.1.weight torch.Size([40]) True
# detector.backbone.body.4.block.3.1.bias torch.Size([40]) True
# detector.backbone.body.5.block.0.0.weight torch.Size([120, 40, 1, 1]) True
# detector.backbone.body.5.block.0.1.weight torch.Size([120]) True
# detector.backbone.body.5.block.0.1.bias torch.Size([120]) True
# detector.backbone.body.5.block.1.0.weight torch.Size([120, 1, 5, 5]) True
# detector.backbone.body.5.block.1.1.weight torch.Size([120]) True
# detector.backbone.body.5.block.1.1.bias torch.Size([120]) True
# detector.backbone.body.5.block.2.fc1.weight torch.Size([32, 120, 1, 1]) True
# detector.backbone.body.5.block.2.fc1.bias torch.Size([32]) True
# detector.backbone.body.5.block.2.fc2.weight torch.Size([120, 32, 1, 1]) True
# detector.backbone.body.5.block.2.fc2.bias torch.Size([120]) True
# detector.backbone.body.5.block.3.0.weight torch.Size([40, 120, 1, 1]) True
# detector.backbone.body.5.block.3.1.weight torch.Size([40]) True
# detector.backbone.body.5.block.3.1.bias torch.Size([40]) True
# detector.backbone.body.6.block.0.0.weight torch.Size([120, 40, 1, 1]) True
# detector.backbone.body.6.block.0.1.weight torch.Size([120]) True
# detector.backbone.body.6.block.0.1.bias torch.Size([120]) True
# detector.backbone.body.6.block.1.0.weight torch.Size([120, 1, 5, 5]) True
# detector.backbone.body.6.block.1.1.weight torch.Size([120]) True
# detector.backbone.body.6.block.1.1.bias torch.Size([120]) True
# detector.backbone.body.6.block.2.fc1.weight torch.Size([32, 120, 1, 1]) True
# detector.backbone.body.6.block.2.fc1.bias torch.Size([32]) True
# detector.backbone.body.6.block.2.fc2.weight torch.Size([120, 32, 1, 1]) True
# detector.backbone.body.6.block.2.fc2.bias torch.Size([120]) True
# detector.backbone.body.6.block.3.0.weight torch.Size([40, 120, 1, 1]) True
# detector.backbone.body.6.block.3.1.weight torch.Size([40]) True
# detector.backbone.body.6.block.3.1.bias torch.Size([40]) True
# detector.backbone.body.7.block.0.0.weight torch.Size([240, 40, 1, 1]) True
# detector.backbone.body.7.block.0.1.weight torch.Size([240]) True
# detector.backbone.body.7.block.0.1.bias torch.Size([240]) True
# detector.backbone.body.7.block.1.0.weight torch.Size([240, 1, 3, 3]) True
# detector.backbone.body.7.block.1.1.weight torch.Size([240]) True
# detector.backbone.body.7.block.1.1.bias torch.Size([240]) True
# detector.backbone.body.7.block.2.0.weight torch.Size([80, 240, 1, 1]) True
# detector.backbone.body.7.block.2.1.weight torch.Size([80]) True
# detector.backbone.body.7.block.2.1.bias torch.Size([80]) True
# detector.backbone.body.8.block.0.0.weight torch.Size([200, 80, 1, 1]) True
# detector.backbone.body.8.block.0.1.weight torch.Size([200]) True
# detector.backbone.body.8.block.0.1.bias torch.Size([200]) True
# detector.backbone.body.8.block.1.0.weight torch.Size([200, 1, 3, 3]) True
# detector.backbone.body.8.block.1.1.weight torch.Size([200]) True
# detector.backbone.body.8.block.1.1.bias torch.Size([200]) True
# detector.backbone.body.8.block.2.0.weight torch.Size([80, 200, 1, 1]) True
# detector.backbone.body.8.block.2.1.weight torch.Size([80]) True
# detector.backbone.body.8.block.2.1.bias torch.Size([80]) True
# detector.backbone.body.9.block.0.0.weight torch.Size([184, 80, 1, 1]) True
# detector.backbone.body.9.block.0.1.weight torch.Size([184]) True
# detector.backbone.body.9.block.0.1.bias torch.Size([184]) True
# detector.backbone.body.9.block.1.0.weight torch.Size([184, 1, 3, 3]) True
# detector.backbone.body.9.block.1.1.weight torch.Size([184]) True
# detector.backbone.body.9.block.1.1.bias torch.Size([184]) True
# detector.backbone.body.9.block.2.0.weight torch.Size([80, 184, 1, 1]) True
# detector.backbone.body.9.block.2.1.weight torch.Size([80]) True
# detector.backbone.body.9.block.2.1.bias torch.Size([80]) True
# detector.backbone.body.10.block.0.0.weight torch.Size([184, 80, 1, 1]) True
# detector.backbone.body.10.block.0.1.weight torch.Size([184]) True
# detector.backbone.body.10.block.0.1.bias torch.Size([184]) True
# detector.backbone.body.10.block.1.0.weight torch.Size([184, 1, 3, 3]) True
# detector.backbone.body.10.block.1.1.weight torch.Size([184]) True
# detector.backbone.body.10.block.1.1.bias torch.Size([184]) True
# detector.backbone.body.10.block.2.0.weight torch.Size([80, 184, 1, 1]) True
# detector.backbone.body.10.block.2.1.weight torch.Size([80]) True
# detector.backbone.body.10.block.2.1.bias torch.Size([80]) True
# detector.backbone.body.11.block.0.0.weight torch.Size([480, 80, 1, 1]) True
# detector.backbone.body.11.block.0.1.weight torch.Size([480]) True
# detector.backbone.body.11.block.0.1.bias torch.Size([480]) True
# detector.backbone.body.11.block.1.0.weight torch.Size([480, 1, 3, 3]) True
# detector.backbone.body.11.block.1.1.weight torch.Size([480]) True
# detector.backbone.body.11.block.1.1.bias torch.Size([480]) True
# detector.backbone.body.11.block.2.fc1.weight torch.Size([120, 480, 1, 1]) True
# detector.backbone.body.11.block.2.fc1.bias torch.Size([120]) True
# detector.backbone.body.11.block.2.fc2.weight torch.Size([480, 120, 1, 1]) True
# detector.backbone.body.11.block.2.fc2.bias torch.Size([480]) True
# detector.backbone.body.11.block.3.0.weight torch.Size([112, 480, 1, 1]) True
# detector.backbone.body.11.block.3.1.weight torch.Size([112]) True
# detector.backbone.body.11.block.3.1.bias torch.Size([112]) True
# detector.backbone.body.12.block.0.0.weight torch.Size([672, 112, 1, 1]) True
# detector.backbone.body.12.block.0.1.weight torch.Size([672]) True
# detector.backbone.body.12.block.0.1.bias torch.Size([672]) True
# detector.backbone.body.12.block.1.0.weight torch.Size([672, 1, 3, 3]) True
# detector.backbone.body.12.block.1.1.weight torch.Size([672]) True
# detector.backbone.body.12.block.1.1.bias torch.Size([672]) True
# detector.backbone.body.12.block.2.fc1.weight torch.Size([168, 672, 1, 1]) True
# detector.backbone.body.12.block.2.fc1.bias torch.Size([168]) True
# detector.backbone.body.12.block.2.fc2.weight torch.Size([672, 168, 1, 1]) True
# detector.backbone.body.12.block.2.fc2.bias torch.Size([672]) True
# detector.backbone.body.12.block.3.0.weight torch.Size([112, 672, 1, 1]) True
# detector.backbone.body.12.block.3.1.weight torch.Size([112]) True
# detector.backbone.body.12.block.3.1.bias torch.Size([112]) True
# detector.backbone.body.13.block.0.0.weight torch.Size([672, 112, 1, 1]) True
# detector.backbone.body.13.block.0.1.weight torch.Size([672]) True
# detector.backbone.body.13.block.0.1.bias torch.Size([672]) True
# detector.backbone.body.13.block.1.0.weight torch.Size([672, 1, 5, 5]) True
# detector.backbone.body.13.block.1.1.weight torch.Size([672]) True
# detector.backbone.body.13.block.1.1.bias torch.Size([672]) True
# detector.backbone.body.13.block.2.fc1.weight torch.Size([168, 672, 1, 1]) True
# detector.backbone.body.13.block.2.fc1.bias torch.Size([168]) True
# detector.backbone.body.13.block.2.fc2.weight torch.Size([672, 168, 1, 1]) True
# detector.backbone.body.13.block.2.fc2.bias torch.Size([672]) True
# detector.backbone.body.13.block.3.0.weight torch.Size([160, 672, 1, 1]) True
# detector.backbone.body.13.block.3.1.weight torch.Size([160]) True
# detector.backbone.body.13.block.3.1.bias torch.Size([160]) True
# detector.backbone.body.14.block.0.0.weight torch.Size([960, 160, 1, 1]) True
# detector.backbone.body.14.block.0.1.weight torch.Size([960]) True
# detector.backbone.body.14.block.0.1.bias torch.Size([960]) True
# detector.backbone.body.14.block.1.0.weight torch.Size([960, 1, 5, 5]) True
# detector.backbone.body.14.block.1.1.weight torch.Size([960]) True
# detector.backbone.body.14.block.1.1.bias torch.Size([960]) True
# detector.backbone.body.14.block.2.fc1.weight torch.Size([240, 960, 1, 1]) True
# detector.backbone.body.14.block.2.fc1.bias torch.Size([240]) True
# detector.backbone.body.14.block.2.fc2.weight torch.Size([960, 240, 1, 1]) True
# detector.backbone.body.14.block.2.fc2.bias torch.Size([960]) True
# detector.backbone.body.14.block.3.0.weight torch.Size([160, 960, 1, 1]) True
# detector.backbone.body.14.block.3.1.weight torch.Size([160]) True
# detector.backbone.body.14.block.3.1.bias torch.Size([160]) True
# detector.backbone.body.15.block.0.0.weight torch.Size([960, 160, 1, 1]) True
# detector.backbone.body.15.block.0.1.weight torch.Size([960]) True
# detector.backbone.body.15.block.0.1.bias torch.Size([960]) True
# detector.backbone.body.15.block.1.0.weight torch.Size([960, 1, 5, 5]) True
# detector.backbone.body.15.block.1.1.weight torch.Size([960]) True
# detector.backbone.body.15.block.1.1.bias torch.Size([960]) True
# detector.backbone.body.15.block.2.fc1.weight torch.Size([240, 960, 1, 1]) True
# detector.backbone.body.15.block.2.fc1.bias torch.Size([240]) True
# detector.backbone.body.15.block.2.fc2.weight torch.Size([960, 240, 1, 1]) True
# detector.backbone.body.15.block.2.fc2.bias torch.Size([960]) True
# detector.backbone.body.15.block.3.0.weight torch.Size([160, 960, 1, 1]) True
# detector.backbone.body.15.block.3.1.weight torch.Size([160]) True
# detector.backbone.body.15.block.3.1.bias torch.Size([160]) True
# detector.backbone.body.16.0.weight torch.Size([960, 160, 1, 1]) True
# detector.backbone.body.16.1.weight torch.Size([960]) True
# detector.backbone.body.16.1.bias torch.Size([960]) True
# detector.backbone.fpn.inner_blocks.0.0.weight torch.Size([256, 160, 1, 1]) True
# detector.backbone.fpn.inner_blocks.0.0.bias torch.Size([256]) True
# detector.backbone.fpn.inner_blocks.1.0.weight torch.Size([256, 960, 1, 1]) True
# detector.backbone.fpn.inner_blocks.1.0.bias torch.Size([256]) True
# detector.backbone.fpn.layer_blocks.0.0.weight torch.Size([256, 256, 3, 3]) True
# detector.backbone.fpn.layer_blocks.0.0.bias torch.Size([256]) True
# detector.backbone.fpn.layer_blocks.1.0.weight torch.Size([256, 256, 3, 3]) True
# detector.backbone.fpn.layer_blocks.1.0.bias torch.Size([256]) True
# detector.rpn.head.conv.0.0.weight torch.Size([256, 256, 3, 3]) True
# detector.rpn.head.conv.0.0.bias torch.Size([256]) True
# detector.rpn.head.cls_logits.weight torch.Size([15, 256, 1, 1]) True
# detector.rpn.head.cls_logits.bias torch.Size([15]) True
# detector.rpn.head.bbox_pred.weight torch.Size([60, 256, 1, 1]) True
# detector.rpn.head.bbox_pred.bias torch.Size([60]) True
# detector.roi_heads.box_head.fc6.weight torch.Size([1024, 12544]) True
# detector.roi_heads.box_head.fc6.bias torch.Size([1024]) True
# detector.roi_heads.box_head.fc7.weight torch.Size([1024, 1024]) True
# detector.roi_heads.box_head.fc7.bias torch.Size([1024]) True
# detector.roi_heads.box_predictor.cls_score.weight torch.Size([2, 1024]) True
# detector.roi_heads.box_predictor.cls_score.bias torch.Size([2]) True
# detector.roi_heads.box_predictor.bbox_pred.weight torch.Size([8, 1024]) True
# detector.roi_heads.box_predictor.bbox_pred.bias torch.Size([8]) True

# %%
@torch.no_grad()
def inference_one_batch(
    batch,
    flow_modules,
    detector,
    device,
    flow_index=0,
    use_mag=True,
    use_valid=False,
    score_thresh=0.3,
):
    detector.eval()
    for m in flow_modules.values():
        m.eval()

    imgs = batch["imgs"].to(device)

    valid = batch.get("valid", None)
    if valid is not None:
        valid = valid.to(device)

    # 1. Predict optical flow
    flow_out = forward_pipeline(
        modules=modules,
        imgs=imgs,
        valid=valid,
    )

    pred_flows = flow_out["flows"]  # [B, Tm, 2, H, W]

    # 2. Build detector input
    flow_x = build_flow_detector_input(
        pred_flows=pred_flows,
        valid=valid,
        flow_index=flow_index,
        use_mag=use_mag,
        use_valid=use_valid,
    )  # [B, C, H, W]

    det_images = [x for x in flow_x]

    # 3. Faster R-CNN inference
    det_out = detector(det_images)  # list[dict]

    # 4. Filter boxes by confidence
    detections = []

    for det in det_out:
        keep = det["scores"] >= score_thresh

        detections.append({
            "boxes": det["boxes"][keep].detach().cpu(),
            "labels": det["labels"][keep].detach().cpu(),
            "scores": det["scores"][keep].detach().cpu(),
        })

    return {
        "pred_flows": pred_flows.detach().cpu(),
        "detector_input": flow_x.detach().cpu(),
        "detections": detections,
    }

# %%
batch = next(iter(train_loader))

result = inference_one_batch(
    batch=batch,
    flow_modules=modules,
    detector=detector,
    device=device,
    flow_index=0,
    use_mag=True,
    use_valid=False,
    score_thresh=0.3,
)

print(result["pred_flows"].shape)

for i, det in enumerate(result["detections"]):
    print(f"sample {i}")
    print(det["boxes"])
    print(det["labels"])
    print(det["scores"])
    
det = result["detections"][0]

boxes = det["boxes"]      # [N, 4], xyxy
labels = det["labels"]    # [N]
scores = det["scores"]    # [N]
# Out:
# torch.Size([2, 3, 2, 352, 1216])
# sample 0
# tensor([[551.1831, 147.4668, 637.8002, 244.3478]])
# tensor([1])
# tensor([0.4019])
# sample 1
# tensor([[ 377.9781,  176.5037,  502.2885,  255.7422],
#         [ 907.6386,   13.3290, 1023.2698,   66.5323]])
# tensor([1, 1])
# tensor([0.9900, 0.6216])

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import cv2


ID_TO_CLASS_NAME = {
    1: 'Object'
}

def flow_to_rgb(flow):
    """
    flow: [2,H,W] torch tensor or numpy array
    returns: [H,W,3] RGB uint8
    """
    if isinstance(flow, torch.Tensor):
        flow = flow.detach().cpu().numpy()

    u = flow[0]
    v = flow[1]

    mag, ang = cv2.cartToPolar(u, v, angleInDegrees=True)

    hsv = np.zeros((flow.shape[1], flow.shape[2], 3), dtype=np.uint8)
    hsv[..., 0] = ang / 2
    hsv[..., 1] = 255
    hsv[..., 2] = np.clip(mag / (np.percentile(mag, 99) + 1e-6) * 255, 0, 255)

    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
    return rgb


def draw_boxes(ax, boxes, labels=None, scores=None, color="lime", linewidth=2, prefix=""):
    """
    boxes: [N,4], xyxy
    labels: [N]
    scores: [N]
    """
    if isinstance(boxes, torch.Tensor):
        boxes = boxes.detach().cpu()

    if labels is not None and isinstance(labels, torch.Tensor):
        labels = labels.detach().cpu()

    if scores is not None and isinstance(scores, torch.Tensor):
        scores = scores.detach().cpu()

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = box.tolist()
        w = x2 - x1
        h = y2 - y1

        rect = patches.Rectangle(
            (x1, y1),
            w,
            h,
            linewidth=linewidth,
            edgecolor=color,
            facecolor="none",
        )
        ax.add_patch(rect)

        text = prefix

        if labels is not None:
            cls_id = int(labels[i])
            cls_name = ID_TO_CLASS_NAME.get(cls_id, str(cls_id))
            text += cls_name

        if scores is not None:
            text += f" {float(scores[i]):.2f}"

        if text.strip():
            ax.text(
                x1,
                max(y1 - 3, 0),
                text,
                color=color,
                fontsize=8,
                bbox=dict(facecolor="black", alpha=0.5, edgecolor="none"),
            )


def visualize_gt_and_pred(
    result,
    batch,
    sample_idx=1,
    flow_index=0,
    score_thresh=0.3,
):
    """
    Top:    GT
    Bottom: Predictions
    """

    pred_flow = result["pred_flows"][sample_idx, flow_index]  # [2,H,W]
    flow_rgb = flow_to_rgb(pred_flow)

    gt = batch["label"][sample_idx]
    pred = result["detections"][sample_idx]

    # ---------------------------
    # Create 2-row figure
    # ---------------------------
    fig, axes = plt.subplots(2, 1, figsize=(14, 8))

    # ===========================
    # TOP: GT
    # ===========================
    ax_gt = axes[0]
    ax_gt.imshow(flow_rgb)
    ax_gt.axis("off")

    draw_boxes(
        ax_gt,
        boxes=gt["boxes"],
        labels=gt["labels"],
        scores=None,
        color="lime",
        linewidth=2,
        prefix="GT ",
    )

    ax_gt.set_title("Ground Truth (Green)")

    # ===========================
    # BOTTOM: Predictions
    # ===========================
    ax_pred = axes[1]
    ax_pred.imshow(flow_rgb)
    ax_pred.axis("off")

    if pred["boxes"].numel() > 0:
        scores = pred["scores"]
    
        # confidence filtering
        keep = scores >= score_thresh
    
        if keep.any():
            draw_boxes(
                ax_pred,
                boxes=pred["boxes"][keep],
                labels=pred["labels"][keep] if "labels" in pred else None,
                scores=scores[keep],
                color="red",
                linewidth=2,
                prefix="Pred ",
            )

    ax_pred.set_title(f"Predictions (Red) | score_thresh={score_thresh}")

    plt.tight_layout()
    plt.show()

# %%
batch = next(iter(train_loader))
result = inference_one_batch(
    batch=batch,
    flow_modules=modules,
    detector=detector,
    device=device,
    flow_index=1,
    use_mag=True,
    use_valid=False,
    score_thresh=0.5,
)

visualize_gt_and_pred(
    result=result,
    batch=batch,
    sample_idx=0,
    flow_index=1,
    score_thresh=0.5,
)
